# %%
#Is there a relationship between the percentage of households using cars for transportation and the percentage of museums classified as art museums in North Carolina counties?

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\allis\anaconda3\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("CENSUS_API_KEY")

# %%
print(api_key)
print("37d5985ad46bc17215096d5b16589ea3d45dada8")
# Out:
# 37d5985ad46bc17215096d5b16589ea3d45dada8
# 37d5985ad46bc17215096d5b16589ea3d45dada8

# %%
url = f"https://api.census.gov/data/2024/acs/acs1?get=NAME,B01001_001E&for=county:*&in=state:37&key=37d5985ad46bc17215096d5b16589ea3d45dada8"

# %%
response = requests.get(url)

# %%
response.text
# Out:
# '[["NAME","B01001_001E","state","county"],\n["Alamance County, North Carolina","183040","37","001"],\n["Brunswick County, North Carolina","167112","37","019"],\n["Buncombe County, North Carolina","279210","37","021"],\n["Burke County, North Carolina","88545","37","023"],\n["Cabarrus County, North Carolina","244925","37","025"],\n["Caldwell County, North Carolina","80739","37","027"],\n["Carteret County, North Carolina","70259","37","031"],\n["Catawba County, North Carolina","167054","37","035"],\n["Chatham County, North Carolina","83874","37","037"],\n["Cleveland County, North Carolina","102194","37","045"],\n["Craven County, North Carolina","104167","37","049"],\n["Cumberland County, North Carolina","338430","37","051"],\n["Davidson County, North Carolina","177809","37","057"],\n["Durham County, North Carolina","343628","37","063"],\n["Forsyth County, North Carolina","398143","37","067"],\n["Franklin County, North Carolina","79771","37","069"],\n["Gaston County, North Carolina","242010","37","071"],\n["Guilford County, North Carolina","558816","37","081"],\n["Harnett County, North Carolina","146096","37","085"],\n["Henderson County, North Carolina","120771","37","089"],\n["Iredell County, North Carolina","206361","37","097"],\n["Johnston County, North Carolina","249794","37","101"],\n["Lee County, North Carolina","68537","37","105"],\n["Lincoln County, North Carolina","97611","37","109"],\n["Mecklenburg County, North Carolina","1206285","37","119"],\n["Moore County, North Carolina","108417","37","125"],\n["Nash County, North Carolina","97990","37","127"],\n["New Hanover County, North Carolina","243333","37","129"],\n["Onslow County, North Carolina","212954","37","133"],\n["Orange County, North Carolina","152877","37","135"],\n["Pender County, North Carolina","70077","37","141"],\n["Pitt County, North Carolina","180783","37","147"],\n["Randolph County, North Carolina","148389","37","151"],\n["Robeson County, North Carolina","118624","37","155"],\n["Rockingham County, North Carolina","93517","37","157"],\n["Rowan County, North Carolina","153384","37","159"],\n["Rutherford County, North Carolina","65587","37","161"],\n["Stanly County, North Carolina","67326","37","167"],\n["Surry County, North Carolina","71547","37","171"],\n["Union County, North Carolina","263386","37","179"],\n["Wake County, North Carolina","1232444","37","183"],\n["Wayne County, North Carolina","120338","37","191"],\n["Wilkes County, North Carolina","66186","37","193"],\n["Wilson County, North Carolina","79958","37","195"]]'

# %%
data = response.json()

# %%
data
# Out:
# [['NAME', 'B01001_001E', 'state', 'county'],
#  ['Alamance County, North Carolina', '183040', '37', '001'],
#  ['Brunswick County, North Carolina', '167112', '37', '019'],
#  ['Buncombe County, North Carolina', '279210', '37', '021'],
#  ['Burke County, North Carolina', '88545', '37', '023'],
#  ['Cabarrus County, North Carolina', '244925', '37', '025'],
#  ['Caldwell County, North Carolina', '80739', '37', '027'],
#  ['Carteret County, North Carolina', '70259', '37', '031'],
#  ['Catawba County, North Carolina', '167054', '37', '035'],
#  ['Chatham County, North Carolina', '83874', '37', '037'],
#  ['Cleveland County, North Carolina', '102194', '37', '045'],
#  ['Craven County, North Carolina', '104167', '37', '049'],
#  ['Cumberland County, North Carolina', '338430', '37', '051'],
#  ['Davidson County, North Carolina', '177809', '37', '057'],
#  ['Durham County, North Carolina', '343628', '37', '063'],
#  ['Forsyth County, North Carolina', '398143', '37', '067'],
#  ['Franklin County, North Carolina', '79771', '37', '069'],
#  ['Gaston County, North Carolina', '242010', '37', '071'],
#  ['Guilford County, North Carolina', '558816', '37', '081'],
#  ['Harnett County, North Carolina', '146096', '37', '085'],
#  ['Henderson County, North Carolina', '120771', '37', '089'],
#  ['Iredell County, North Carolina', '206361', '37', '097'],
#  ['Johnston County, North Carolina', '249794', '37', '101'],
#  ['Lee County, North Carolina', '68537', '37', '105'],
#  ['Lincoln County, North Carolina', '97611', '37', '109'],
#  ['Mecklenburg County, North Carolina', '1206285', '37', '119'],
#  ['Moore County, North Carolina', '108417', '37', '125'],
#  ['Nash County, North Carolina', '97990', '37', '127'],
#  ['New Hanover County, North Carolina', '243333', '37', '129'],
#  ['Onslow County, North Carolina', '212954', '37', '133'],
#  ['Orange County, North Carolina', '152877', '37', '135'],
#  ['Pender County, North Carolina', '70077', '37', '141'],
#  ['Pitt County, North Carolina', '180783', '37', '147'],
#  ['Randolph County, North Carolina', '148389', '37', '151'],
#  ['Robeson County, North Carolina', '118624', '37', '155'],
#  ['Rockingham County, North Carolina', '93517', '37', '157'],
#  ['Rowan County, North Carolina', '153384', '37', '159'],
#  ['Rutherford County, North Carolina', '65587', '37', '161'],
#  ['Stanly County, North Carolina', '67326', '37', '167'],
#  ['Surry County, North Carolina', '71547', '37', '171'],
#  ['Union County, North Carolina', '263386', '37', '179'],
#  ['Wake County, North Carolina', '1232444', '37', '183'],
#  ['Wayne County, North Carolina', '120338', '37', '191'],
#  ['Wilkes County, North Carolina', '66186', '37', '193'],
#  ['Wilson County, North Carolina', '79958', '37', '195']]

# %%
dfcsv = pd.read_csv(r"C:\Users\allis\Downloads\museums_by_state.csv")

# %%
variables = ",".join([
    "NAME",            # County name
    "B01003_001E",     # Total population
    "B08141_001E",     # Total: Means of Transportation to Work by Vehicles Available (People that drive)
    "B08141_016E",     # Estimate!!Total:!!Public transportation:
    "B08141_017E",     # Estimate!!Total:!!Public transportation:!!No vehicle available
    "B08141_021E",     #Estimate!!Total:!!Walked:

])

# %%
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#                                   NAME B01001_001E state county
# 0      Alamance County, North Carolina      183040    37    001
# 1     Brunswick County, North Carolina      167112    37    019
# 2      Buncombe County, North Carolina      279210    37    021
# 3         Burke County, North Carolina       88545    37    023
# 4      Cabarrus County, North Carolina      244925    37    025
# 5      Caldwell County, North Carolina       80739    37    027
# 6      Carteret County, North Carolina       70259    37    031
# 7       Catawba County, North Carolina      167054    37    035
# 8       Chatham County, North Carolina       83874    37    037
# 9     Cleveland County, North Carolina      102194    37    045
# 10       Craven County, North Carolina      104167    37    049
# 11   Cumberland County, North Carolina      338430    37    051
# 12     Davidson County, North Carolina      177809    37    057
# 13       Durham County, North Carolina      343628    37    063
# 14      Forsyth County, North Carolina      398143    37    067
# 15     Franklin County, North Carolina       79771    37    069
# 16       Gaston County, North Carolina      242010    37    071
# 17     Guilford County, North Carolina      558816    37    081
# 18      Harnett County, North Carolina      146096    37    085
# 19    Henderson County, North Carolina      120771    37    089
# 20      Iredell County, North Carolina      206361    37    097
# 21     Johnston County, North Carolina      249794    37    101
# 22          Lee County, North Carolina       68537    37    105
# 23      Lincoln County, North Carolina       97611    37    109
# 24  Mecklenburg County, North Carolina     1206285    37    119
# 25        Moore County, North Carolina      108417    37    125
# 26         Nash County, North Carolina       97990    37    127
# 27  New Hanover County, North Carolina      243333    37    129
# 28       Onslow County, North Carolina      212954    37    133
# 29       Orange County, North Carolina      152877    37    135
# 30       Pender County, North Carolina       70077    37    141
# 31         Pitt County, North Carolina      180783    37    147
# 32     Randolph County, North Carolina      148389    37    151
# 33      Robeson County, North Carolina      118624    37    155
# 34   Rockingham County, North Carolina       93517    37    157
# 35        Rowan County, North Carolina      153384    37    159
# 36   Rutherford County, North Carolina       65587    37    161
# 37       Stanly County, North Carolina       67326    37    167
# 38        Surry County, North Carolina       71547    37    171
# 39        Union County, North Carolina      263386    37    179
# 40         Wake County, North Carolina     1232444    37    183
# 41        Wayne County, North Carolina      120338    37    191
# 42       Wilkes County, North Carolina       66186    37    193
# 43       Wilson County, North Carolina       79958    37    195

# %%
numeric_cols = [
    #"NAME",            # County name
    "B01003_001E",     # Total population
    "B08141_001E",     # Total: Means of Transportation to Work by Vehicles Available (People that drive)
    "B08141_016E",     # Estimate!!Total:!!Public transportation:
    "B08141_017E",     # Estimate!!Total:!!Public transportation:!!No vehicle available
    "B08141_021E"      #Estimate!!Total:!!Walked:
]

#for col in numeric_cols:
#   df[col] = pd.to_numeric(df[col], errors="coerce") # coerce -> If something cannot be converted to a number, don’t crash. Instead, turn it into NaN.

df = df.rename(columns={
    #"NAME": "County_Name",
    "B01003_001E": "Total_Population",
    "B08141_001E": "Total Transportation By Vehicles Available",
    "B08141_016E": "Total Public Transportation",
    "B08141_017E": "No_Vehicle_Available",
    "B08141_021E": "Walked"
})

df.head()
# Out:
#                                NAME B01001_001E state county
# 0   Alamance County, North Carolina      183040    37    001
# 1  Brunswick County, North Carolina      167112    37    019
# 2   Buncombe County, North Carolina      279210    37    021
# 3      Burke County, North Carolina       88545    37    023
# 4   Cabarrus County, North Carolina      244925    37    025

# %%
df.isnull().sum()
# Out:
# NAME           0
# B01001_001E    0
# state          0
# county         0
# dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x="Total Public Transportation", y="Walked")
plt.title("Total Public Transportation vs Walked to Work (NC Counties)")
plt.xlabel("Total Public Transportation")
plt.ylabel("Walked to Work")
plt.show()

# %%
dfboth = pd.merge(df, dfcsv, on="NAME") #combines the data sets using the shared variable of county name so I can use variables from both for my visualization

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=dfboth, x="Total Public Transportation", y="Walked")
plt.title("Total Public Transportation vs Walked to Work (NC Counties)")
plt.xlabel("Total Public Transportation")
plt.ylabel("Walked to Work")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(df[""], bins=20)
plt.title("")
plt.xlabel("")
plt.ylabel("")
plt.show()
