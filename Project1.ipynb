# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\allis\anaconda3\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dotenv import load_dotenv, find_dotenv

# %%
env_content = """
CENSUS_API_KEY=37d5985ad46bc17215096d5b16589ea3d45dada8
"""

with open(".env", "w") as f:
    f.write(env_content.strip())

print("📁 Brand new .env file force-created right next to your notebook!")
from dotenv import load_dotenv
print("Loading status:", load_dotenv(".env", override=True))
# Out:
# '\n\n#env_content = "\nAPI_KEY=c0Z1T3OL5XKVXcj1vXfQUGIWrbFTma7hXerNSugr\n"\n\nwith open(".env", "w") as f:\n    f.write(env_content.strip())\n\nprint("📁 Brand new .env file force-created right next to your notebook!")\nfrom dotenv import load_dotenv\nprint("Loading status:", load_dotenv(".env", override=True))\n\n'

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("API_KEY")

# %%
print(api_key)
# Out:
# c0Z1T3OL5XKVXcj1vXfQUGIWrbFTma7hXerNSugr

# %%
url = f"https://api.data.gov/ed/collegescorecard/v1/schools?api_key=api_key"

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [403]>
